# %% [markdown]
# <a href="https://colab.research.google.com/github/vvrgit/ML-Optimization/blob/main/LinearOptimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Import linprog funbction from scipy
from scipy.optimize import linprog

obj=[-6,-5]  #Objective Function

#Constraints
lhs_ieq=[[1,1],[3,2]]
rhs_ieq=[5,12]

#decisiopn Variable boundaries
bnd=[(0,float("inf")),(0,float("inf"))]


# Implementation of linprog function
opt=linprog(c=obj,A_ub=lhs_ieq,b_ub=rhs_ieq,bounds=bnd,method="Simplex")

#Solution
opt.x
# Out:
# <ipython-input-1-b19ffc405774>:15: DeprecationWarning: `method='simplex'` is deprecated and will be removed in SciPy 1.11.0. Please use one of the HiGHS solvers (e.g. `method='highs'`) in new code.
#   opt=linprog(c=obj,A_ub=lhs_ieq,b_ub=rhs_ieq,bounds=bnd,method="Simplex")
# array([2., 3.])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Thank You**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from scipy.optimize import linprog
obj=[-40,-30]
#Constraints
lhs_ieq=[[2,1],[1,1]]
rhs_ieq=[100,80]
#decisiopn Variable boundaries
bnd=[(0,float("inf")),(0,float("inf"))]
# Implementation of linprog function
opt=linprog(c=obj,A_ub=lhs_ieq,b_ub=rhs_ieq,bounds=bnd,method="Simplex")

#Solution
opt.x
# Out:
# <ipython-input-1-d7aa27640daa>:9: DeprecationWarning: `method='simplex'` is deprecated and will be removed in SciPy 1.11.0. Please use one of the HiGHS solvers (e.g. `method='highs'`) in new code.
#   opt=linprog(c=obj,A_ub=lhs_ieq,b_ub=rhs_ieq,bounds=bnd,method="Simplex")
# array([20., 60.])
